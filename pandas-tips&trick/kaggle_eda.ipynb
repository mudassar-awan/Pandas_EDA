# %% [markdown]
# # Google App Store EDA

# %%
# import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../data-sets/googleplaystore.csv')

# %%
import os

# This tells you the path of the folder Python is currently "sitting" in
current_path = os.getcwd()

print(f"Current Working Directory: {current_path}")
print(f"Files inside this folder: {os.listdir()}")
# Out:
# Current Working Directory: c:\Users\pc\Desktop\Pandas_EDA\pandas-tips&trick
# Files inside this folder: ['kaggle_eda.ipynb', 'pandas_on_pak_pop_02.ipynb', 'tips_dataset.csv', 'tips_datset.xlsx', 'titanci.xlsx', 'updated-pandas-tips.ipynb', 'ydata_profiling.ipynb']

# %%
# check the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
#  13  Unnamed: 13     0 non-null      float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
# lets have a look at the first 5 rows
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0                                                App  ART_AND_DESIGN     4.1
# 1                                                App  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.sample(10) # it take random 10 rows from the dataframe
# Out:
#                                              App      Category  Rating  \
# 8689   Best DP and Status (Daily Updates Photos)        FAMILY     4.1
# 3891                       Create A Superhero HD        FAMILY     3.3
# 8443                         Meme Generator Free        FAMILY     4.4
# 5073                  PhotoScan by Google Photos   PHOTOGRAPHY     4.3
# 8879                        Riptide GP: Renegade          GAME     4.7
# 5648                   Five Nights at Freddy's 3          GAME     4.7
# 10404                Top Puzzles Volvo FH Trucks        FAMILY     NaN
# 289             Mobile Doc Scanner (MDScan) Lite      BUSINESS     4.2
# 3490                 Do It Later: Tasks & To-Dos  PRODUCTIVITY     4.5
# 4901                   Assassin's Creed Identity          GAME     3.7
#
#        Reviews                Size     Installs  Type  Price Content Rating  \
# 8689      3003                3.2M   1,000,000+  Free      0       Everyone
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews  Unnamed: 13
# count  9367.000000  1.084100e+04          0.0
# mean      4.191513  4.441119e+05          NaN
# std       0.515735  2.927629e+06          NaN
# min       1.000000  0.000000e+00          NaN
# 25%       4.000000  3.800000e+01          NaN
# 50%       4.300000  2.094000e+03          NaN
# 75%       4.500000  5.476800e+04          NaN
# max       5.000000  7.815831e+07          NaN

# %% [markdown]
# ## Assignment
# Write down all the numeric values and make them numeric
# 1. size
# 2. install
# 3. price

# %%
# to do this lets have a look on the unique values 
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df['Size'].nunique()
# Out:
# 461

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 253k                     1
# 992k                     1
# 658k                     1
# 73k                      1
# 246k                     1
# Name: count, Length: 461, dtype: int64

# %%
df['Size'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Installs

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %% [markdown]
# ##  do it as numeric columns and do it into differents groupgs following the binning methods

# %% [markdown]
# # how to handle price

# %%
df['Price'].value_counts()
# Out:
# Price
# 0          10041
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
#            ...
# $3.61          1
# $394.99        1
# $1.26          1
# $1.20          1
# $1.04          1
# Name: count, Length: 92, dtype: int64

# %%
df['Price'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Clean and convert to float
df['Price'] = df['Price'].str.replace('$', '', regex=False).astype(float)

# %%
# Now you can perform EDA functions correctly:
print(df['Price'].describe()) # Shows mean, max, min, etc.
print(df['Price'].median())   # Shows the middle price point
# Out:
# count    10841.000000
# mean         1.027273
# std         15.948971
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        400.000000
# Name: Price, dtype: float64
# 0.0

# %%
df['Price'].value_counts()
# Out:
# Price
# 0.00      10041
# 0.99        148
# 2.99        129
# 1.99         73
# 4.99         72
#           ...
# 3.61          1
# 394.99        1
# 1.26          1
# 1.20          1
# 1.04          1
# Name: count, Length: 92, dtype: int64

# %% [markdown]
# # remove $(dollar) sign

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    10040
# Paid      800
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0                                                App  ART_AND_DESIGN     4.1
# 1                                                App  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159   19M      10,000+  Free    0.0       Everyone
# 1      967   14M     500,000+  Free    0.0       Everyone
# 2    87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3   215644   25M  50,000,000+  Free    0.0           Teen
# 4      967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 253k                     1
# 992k                     1
# 658k                     1
# 73k                      1
# 246k                     1
# Name: count, Length: 461, dtype: int64

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
# we need to convert kb into mb and remove M from all data points
